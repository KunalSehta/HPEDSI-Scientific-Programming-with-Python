# %% [markdown]
# Write a function wordcount() that takes the name of a text file as input and prints the number of occurrences of every word in the file. You function should be case-insensitive so 'Hello' and 'hello' are treated as the same word. You should ignore words of length 2 or less. The results printed will be ordered from the most frequent to the least frequent.  Hint: dictionary  and list.  Test your implementation on file great_expectations.txt.
#
# <br>
# The function should work like this<br>
#
# <code>wordcount('example_file.txt')
#             the          50
#             hello         5
#             can           3
#             was           3
#
# </code>

# %%
def wordcount(file1):
    file = open(file1, 'r')
    content = ' '.join(line for line in file.read().splitlines())
    content = content.split(' ')
    
    freqs = {}
    for word in content:
        word = word.lower()
        if word not in freqs:
            freqs[word] = 1
        else:
            freqs[word] += 1
        file.close()
    return freqs

# %%
wordcount('great_expectations.txt')
# Out:
# {'the': 8240,
#  'project': 83,
#  'gutenberg': 25,
#  'ebook': 9,
#  'of': 4481,
#  'great': 176,
#  'expectations,': 7,
#  'by': 768,
#  'charles': 4,
#  'dickens': 4,
#  '': 4402,
#  'this': 685,
#  'is': 552,
#  'for': 1266,
#  'use': 35,
#  'anyone': 5,
#  'anywhere': 6,
#  'at': 1599,
#  'no': 499,
#  'cost': 4,
#  'and': 6746,
#  'with': 1760,
#  'almost': 44,
#  'restrictions': 2,
#  'whatsoever.': 2,
#  'you': 1651,
#  'may': 163,
#  'copy': 10,
#  'it,': 307,
#  'give': 87,
#  'it': 1911,
#  'away': 97,
#  'or': 604,
#  're-use': 2,
#  'under': 150,
#  'terms': 31,
#  'license': 11,
#  'included': 3,
#  'online': 4,
#  'www.gutenberg.org': 2,
#  'title:': 1,
#  'expectations': 14,
#  'author:': 1,
#  'posting': 2,
#  'date:': 2,
#  'august': 1,
#  '20,': 1,
#  '2008': 1,
#  '[ebook': 1,
#  '#1400]': 1,
#  'release': 4,
#  'july,': 1,
#  '1998': 1,
#  'last': 150,
#  'updated:': 1,
#  'october': 1,
#  '17,': 1,
#  '2015': 1,
#  'language:': 1,
#  'english': 3,
#  '***': 7,
#  'start': 15,
#  'produced': 10,
#  'an': 444,
#  'anonymous': 3,
#  'volunteer': 3,
#  '[1867': 1,
#  'edition]': 2,
#  '[project': 1,
#  "editor's": 1,
#  'note:': 1,
#  'there': 479,
#  'also': 26,
#  'another': 115,
#  'version': 3,
#  'work': 69,
#  'etext98/grexp10.txt': 1,
#  'scanned': 1,
#  'from': 576,
#  'a': 4022,
#  'different': 22,
#  'chapter': 62,
#  'i': 5674,
#  'my': 2028,
#  "father's": 11,
#  'family': 27,
#  'name': 68,
#  'being': 255,
#  'pirrip,': 4,
#  'christian': 9,
#  'philip,': 1,
#  'infant': 5,
#  'tongue': 5,
#  'could': 446,
#  'make': 156,
#  'both': 124,
#  'names': 10,
#  'nothing': 141,
#  'longer': 16,
#  'more': 325,
#  'explicit': 1,
#  'than': 295,
#  'pip.': 32,
#  'so,': 78,
#  'called': 59,
#  'myself': 140,
#  'pip,': 73,
#  'came': 217,
#  'to': 5063,
#  'be': 987,
#  'pirrip': 1,
#  'as': 1706,
#  'name,': 24,
#  'on': 1292,
#  'authority': 7,
#  'his': 1839,
#  'tombstone': 4,
#  'sister,--mrs.': 1,
#  'joe': 302,
#  'gargery,': 10,
#  'who': 283,
#  'married': 23,
#  'blacksmith.': 2,
#  'never': 292,
#  'saw': 243,
#  'father': 37,
#  'mother,': 6,
#  'any': 296,
#  'likeness': 7,
#  'either': 27,
#  'them': 246,
#  '(for': 9,
#  'their': 175,
#  'days': 42,
#  'were': 749,
#  'long': 145,
#  'before': 243,
#  'photographs),': 1,
#  'first': 157,
#  'fancies': 1,
#  'regarding': 8,
#  'what': 516,
#  'they': 347,
#  'like': 287,
#  'unreasonably': 2,
#  'derived': 14,
#  'tombstones.': 1,
#  'shape': 5,
#  'letters': 5,
#  "father's,": 1,
#  'gave': 106,
#  'me': 1202,
#  'odd': 12,
#  'idea': 35,
#  'that': 2708,
#  'he': 2026,
#  'was': 2691,
#  'square,': 3,
#  'stout,': 1,
#  'dark': 44,
#  'man,': 70,
#  'curly': 3,
#  'black': 72,
#  'hair.': 11,
#  'character': 15,
#  'turn': 42,
#  'inscription,': 1,
#  '"also': 2,
#  'georgiana': 5,
#  'wife': 13,
#  'above,"': 1,
#  'drew': 31,
#  'childish': 4,
#  'conclusion': 3,
#  'mother': 19,
#  'freckled': 1,
#  'sickly.': 1,
#  'five': 32,
#  'little': 340,
#  'stone': 12,
#  'lozenges,': 1,
#  'each': 43,
#  'about': 293,
#  'foot': 15,
#  'half': 66,
#  'long,': 15,
#  'which': 450,
#  'arranged': 5,
#  'in': 2948,
#  'neat': 8,
#  'row': 7,
#  'beside': 18,
#  'grave,': 4,
#  'sacred': 4,
#  'memory': 7,
#  'brothers': 1,
#  'mine,--who': 1,
#  'up': 479,
#  'trying': 17,
#  'get': 148,
#  'living,': 6,
#  'exceedingly': 13,
#  'early': 30,
#  'universal': 1,
#  'struggle,--i': 1,
#  'am': 220,
#  'indebted': 1,
#  'belief': 9,
#  'religiously': 1,
#  'entertained': 4,
#  'had': 2058,
#  'all': 658,
#  'been': 593,
#  'born': 8,
#  'backs': 5,
#  'hands': 115,
#  'trousers-pockets,': 1,
#  'taken': 87,
#  'out': 607,
#  'state': 59,
#  'existence.': 3,
#  'ours': 5,
#  'marsh': 14,
#  'country,': 15,
#  'down': 276,
#  'river,': 18,
#  'within,': 5,
#  'river': 21,
#  'wound,': 2,
#  'twenty': 21,
#  'miles': 12,
#  'sea.': 5,
#  'most': 119,
#  'vivid': 2,
#  'broad': 12,
#  'impression': 14,
#  'identity': 2,
#  'things': 40,
#  'seems': 9,
#  'have': 1055,
#  'gained': 3,
#  'memorable': 7,
#  'raw': 4,
#  'afternoon': 11,
#  'towards': 88,
#  'evening.': 4,
#  'such': 181,
#  'time': 208,
#  'found': 141,
#  'certain': 53,
#  'bleak': 2,
#  'place': 79,
#  'overgrown': 5,
#  'nettles': 1,
#  'churchyard;': 1,
#  'philip': 4,
#  'late': 27,
#  'parish,': 3,
#  'above,': 6,
#  'dead': 26,
#  'buried;': 2,
#  'alexander,': 1,
#  'bartholomew,': 1,
#  'abraham,': 1,
#  'tobias,': 1,
#  'roger,': 1,
#  'children': 21,
#  'aforesaid,': 1,
#  'flat': 13,
#  'wilderness': 4,
#  'beyond': 25,
#  'churchyard,': 8,
#  'intersected': 1,
#  'dikes': 3,
#  'mounds': 2,
#  'gates,': 5,
#  'scattered': 8,
#  'cattle': 4,
#  'feeding': 1,
#  'marshes;': 1,
#  'low': 45,
#  'leaden': 2,
#  'line': 13,
#  'river;': 3,
#  'distant': 12,
#  'savage': 5,
#  'lair': 1,
#  'wind': 31,
#  'rushing': 6,
#  'sea;': 1,
#  'small': 39,
#  'bundle': 11,
#  'shivers': 2,
#  'growing': 14,
#  'afraid': 37,
#  'beginning': 21,
#  'cry,': 4,
#  '"hold': 4,
#  'your': 385,
#  'noise!"': 1,
#  'cried': 48,
#  'terrible': 17,
#  'voice,': 26,
#  'man': 178,
#  'started': 20,
#  'among': 74,
#  'graves': 4,
#  'side': 66,
#  'church': 26,
#  'porch.': 2,
#  '"keep': 3,
#  'still,': 20,
#  'devil,': 1,
#  "i'll": 63,
#  'cut': 33,
#  'throat!"': 1,
#  'fearful': 6,
#  'coarse': 20,
#  'gray,': 5,
#  'iron': 32,
#  'leg.': 6,
#  'hat,': 7,
#  'broken': 19,
#  'shoes,': 1,
#  'old': 290,
#  'rag': 5,
#  'tied': 13,
#  'round': 152,
#  'head.': 20,
#  'soaked': 1,
#  'water,': 13,
#  'smothered': 1,
#  'mud,': 8,
#  'lamed': 1,
#  'stones,': 3,
#  'flints,': 1,
#  'stung': 2,
#  'nettles,': 2,
#  'torn': 5,
#  'briars;': 1,
#  'limped,': 1,
#  'shivered,': 1,
#  'glared,': 1,
#  'growled;': 1,
#  'whose': 40,
#  'teeth': 8,
#  'chattered': 2,
#  'head': 136,
#  'seized': 6,
#  'chin.': 1,
#  '"oh!': 8,
#  "don't": 244,
#  'throat,': 4,
#  'sir,"': 39,
#  'pleaded': 5,
#  'terror.': 4,
#  '"pray': 3,
#  'do': 351,
#  'sir."': 21,
#  '"tell': 9,
#  'us': 144,
#  'name!"': 1,
#  'said': 1168,
#  'man.': 24,
#  '"quick!"': 1,
#  '"pip,': 10,
#  '"once': 4,
#  'more,"': 1,
#  'staring': 24,
#  'me.': 210,
#  '"give': 4,
#  'mouth!"': 1,
#  '"pip.': 1,
#  '"show': 2,
#  'where': 175,
#  'live,"': 2,
#  '"pint': 1,
#  'place!"': 2,
#  'pointed': 7,
#  'our': 261,
#  'village': 16,
#  'lay,': 4,
#  'in-shore': 2,
#  'alder-trees': 1,
#  'pollards,': 1,
#  'mile': 4,
#  'church.': 2,
#  'after': 280,
#  'looking': 177,
#  'moment,': 36,
#  'turned': 80,
#  'upside': 5,
#  'down,': 38,
#  'emptied': 4,
#  'pockets.': 4,
#  'but': 903,
#  'piece': 26,
#  'bread.': 2,
#  'when': 824,
#  'itself,--for': 1,
#  'so': 619,
#  'sudden': 15,
#  'strong': 49,
#  'made': 280,
#  'go': 209,
#  'over': 222,
#  'heels': 3,
#  'me,': 405,
#  'steeple': 1,
#  'feet,--when': 1,
#  'itself,': 3,
#  'say,': 50,
#  'seated': 12,
#  'high': 40,
#  'tombstone,': 2,
#  'trembling': 4,
#  'while': 174,
#  'ate': 8,
#  'bread': 18,
#  'ravenously.': 1,
#  '"you': 188,
#  'young': 142,
#  'dog,"': 1,
#  'licking': 1,
#  'lips,': 10,
#  '"what': 89,
#  'fat': 8,
#  'cheeks': 1,
#  "ha'": 10,
#  'got."': 1,
#  'believe': 51,
#  'fat,': 1,
#  'though': 110,
#  'undersized': 1,
#  'years,': 11,
#  'not': 970,
#  'strong.': 1,
#  '"darn': 1,
#  'if': 719,
#  "couldn't": 37,
#  'eat': 13,
#  'em,"': 1,
#  'threatening': 2,
#  'shake': 18,
#  'head,': 53,
#  '"and': 188,
#  "han't": 4,
#  'mind': 107,
#  'to\'t!"': 1,
#  'earnestly': 3,
#  'expressed': 14,
#  'hope': 64,
#  "wouldn't,": 3,
#  'held': 79,
#  'tighter': 2,
#  'put': 233,
#  'me;': 44,
#  'partly,': 2,
#  'keep': 69,
#  'upon': 360,
#  'it;': 34,
#  'crying.': 1,
#  '"now': 12,
#  'lookee': 3,
#  'here!"': 4,
#  '"where\'s': 1,
#  'mother?"': 2,
#  '"there,': 8,
#  'sir!"': 7,
#  'i.': 97,
#  'started,': 2,
#  'short': 34,
#  'run,': 2,
#  'stopped': 55,
#  'looked': 318,
#  'shoulder.': 11,
#  'timidly': 2,
#  'explained.': 3,
#  'georgiana.': 1,
#  "that's": 45,
#  'mother."': 5,
#  '"oh!"': 11,
#  'he,': 74,
#  'coming': 89,
#  'back.': 24,
#  'alonger': 9,
#  '"yes,': 55,
#  'i;': 7,
#  '"him': 2,
#  'too;': 6,
#  'parish."': 1,
#  '"ha!"': 1,
#  'muttered': 2,
#  'then,': 99,
#  'considering.': 2,
#  '"who': 18,
#  "d'ye": 1,
#  'live': 16,
#  "with,--supposin'": 1,
#  "you're": 40,
#  'kindly': 7,
#  'let': 106,
#  'live,': 4,
#  'about?"': 4,
#  '"my': 35,
#  'sister,': 49,
#  'sir,--mrs.': 1,
#  'gargery,--wife': 1,
#  'blacksmith,': 6,
#  '"blacksmith,': 1,
#  'eh?"': 2,
#  'he.': 32,
#  'darkly': 3,
#  'leg': 20,
#  'several': 29,
#  'times,': 25,
#  'closer': 3,
#  'took': 237,
#  'arms,': 17,
#  'tilted': 6,
#  'back': 154,
#  'far': 84,
#  'hold': 52,
#  'eyes': 120,
#  'powerfully': 2,
#  'into': 490,
#  'mine,': 25,
#  'mine': 16,
#  'helplessly': 3,
#  'his.': 6,
#  'here,"': 13,
#  'said,': 150,
#  '"the': 49,
#  'question': 47,
#  'whether': 95,
#  'live.': 2,
#  'know': 281,
#  'file': 15,
#  'is?"': 4,
#  'wittles': 3,
#  'more,': 28,
#  'greater': 18,
#  'sense': 28,
#  'helplessness': 1,
#  'danger.': 3,
#  'file."': 1,
#  'again.': 63,
#  'wittles."': 2,
#  'bring': 36,
#  "'em": 26,
#  'me."': 41,
#  '"or': 15,
#  'heart': 55,
#  'liver': 5,
#  'out."': 6,
#  'dreadfully': 6,
#  'frightened,': 1,
#  'giddy': 2,
#  'clung': 1,
#  'him': 712,
#  'hands,': 41,
#  '"if': 53,
#  'would': 574,
#  'please': 10,
#  'upright,': 2,
#  'sir,': 22,
#  'perhaps': 29,
#  "shouldn't": 13,
#  'sick,': 1,
#  'attend': 5,
#  'more."': 10,
#  'tremendous': 5,
#  'dip': 2,
#  'roll,': 3,
#  'jumped': 2,
#  'its': 155,
#  'own': 168,
#  'weathercock.': 1,
#  'upright': 3,
#  'position': 8,
#  'top': 24,
#  'stone,': 2,
#  'went': 278,
#  'these': 131,
#  'terms:--': 2,
#  'to-morrow': 13,
#  'morning': 31,
#  'early,': 3,
#  'wittles.': 1,
#  'lot': 6,
#  'battery': 5,
#  'yonder.': 1,
#  'dare': 22,
#  'say': 183,
#  'word': 58,
#  'sign': 9,
#  'concerning': 13,
#  'having': 144,
#  'seen': 132,
#  'person': 51,
#  'sumever,': 1,
#  'shall': 97,
#  'fail,': 1,
#  'words': 36,
#  'partickler,': 3,
#  'matter': 34,
#  'how': 235,
#  'is,': 30,
#  'tore': 3,
#  'out,': 97,
#  'roasted,': 1,
#  'ate.': 1,
#  'now,': 144,
#  "ain't": 50,
#  'alone,': 16,
#  'think': 202,
#  'am.': 4,
#  "there's": 34,
#  'hid': 6,
#  'comparison': 3,
#  'angel.': 1,
#  'hears': 6,
#  'speak.': 5,
#  'has': 107,
#  'secret': 24,
#  'way': 172,
#  'pecooliar': 1,
#  'himself,': 27,
#  'getting': 45,
#  'boy,': 42,
#  'heart,': 12,
#  'liver.': 1,
#  'wain': 1,
#  'boy': 61,
#  'attempt': 9,
#  'hide': 5,
#  'himself': 130,
#  'lock': 6,
#  'door,': 56,
#  'warm': 13,
#  'bed,': 24,
#  'tuck': 1,
#  'up,': 75,
#  'draw': 5,
#  'clothes': 25,
#  'comfortable': 10,
#  'safe,': 5,
#  'will': 160,
#  'softly': 11,
#  'creep': 6,
#  'tear': 7,
#  'open.': 3,
#  'keeping': 27,
#  'harming': 1,
#  'present': 45,
#  'difficulty.': 2,
#  'find': 58,
#  'wery': 4,
#  'hard': 47,
#  'off': 119,
#  'inside.': 1,
#  'say?"': 6,
#  'file,': 5,
#  'bits': 5,
#  'food': 4,
#  'could,': 15,
#  'come': 313,
#  'battery,': 7,
#  'morning.': 12,
#  '"say': 10,
#  'lord': 11,
#  'strike': 9,
#  'don\'t!"': 2,
#  'down.': 21,
#  '"now,"': 9,
#  'pursued,': 8,
#  'remember': 32,
#  "you've": 11,
#  'undertook,': 1,
#  'home!"': 3,
#  '"goo-good': 1,
#  'night,': 73,
#  'faltered.': 1,
#  '"much': 5,
#  'that!"': 5,
#  'glancing': 12,
#  'cold': 29,
#  'wet': 9,
#  'flat.': 1,
#  '"i': 431,
#  'wish': 46,
#  'frog.': 1,
#  'eel!"': 1,
#  'same': 107,
#  'time,': 87,
#  'hugged': 2,
#  'shuddering': 2,
#  'body': 9,
#  'arms,--clasping': 1,
#  'together,--and': 1,
#  'limped': 2,
#  'wall.': 10,
#  'go,': 19,
#  'picking': 5,
#  'brambles': 4,
#  'bound': 17,
#  'green': 26,
#  'mounds,': 1,
#  'eluding': 1,
#  'people,': 7,
#  'stretching': 4,
#  'cautiously': 1,
#  'graves,': 3,
#  'twist': 3,
#  'ankle': 1,
#  'pull': 11,
#  'in.': 16,
#  'wall,': 15,
#  'got': 234,
#  'legs': 22,
#  'numbed': 1,
#  'stiff,': 1,
#  'then': 270,
#  'look': 158,
#  'turning,': 2,
#  'set': 80,
#  'face': 106,
#  'home,': 34,
#  'best': 77,
#  'legs.': 4,
#  'presently': 31,
#  'shoulder,': 17,
#  'going': 212,
#  'again': 114,
#  'still': 120,
#  'hugging': 3,
#  'sore': 4,
#  'feet': 18,
#  'stones': 9,
#  'dropped': 40,
#  'marshes': 23,
#  'here': 110,
#  'there,': 93,
#  'stepping-places': 1,
#  'rains': 1,
#  'heavy': 32,
#  'tide': 22,
#  'just': 81,
#  'horizontal': 2,
#  'him;': 19,
#  'line,': 2,
#  'nearly': 15,
#  'nor': 45,
#  'yet': 84,
#  'black;': 2,
#  'sky': 4,
#  'angry': 7,
#  'red': 26,
#  'lines': 3,
#  'dense': 2,
#  'intermixed.': 1,
#  'edge': 5,
#  'faintly': 7,
#  'only': 159,
#  'two': 207,
#  'prospect': 5,
#  'seemed': 137,
#  'standing': 41,
#  'upright;': 1,
#  'one': 411,
#  'beacon': 1,
#  'sailors': 1,
#  'steered,--like': 1,
#  'unhooped': 1,
#  'cask': 3,
#  'pole,--an': 1,
#  'ugly': 7,
#  'thing': 63,
#  'near': 61,
#  'other,': 15,
#  'gibbet,': 2,
#  'some': 316,
#  'chains': 4,
#  'hanging': 16,
#  'once': 103,
#  'pirate.': 1,
#  'limping': 3,
#  'latter,': 1,
#  'pirate': 3,
#  'life,': 36,
#  'hook': 1,
#  'thought': 201,
#  'so;': 4,
#  'lifting': 5,
#  'heads': 9,
#  'gaze': 1,
#  'him,': 197,
#  'wondered': 13,
#  'too.': 22,
#  'horrible': 8,
#  'see': 232,
#  'signs': 3,
#  'him.': 113,
#  'now': 178,
#  'frightened': 2,
#  'again,': 136,
#  'ran': 37,
#  'home': 61,
#  'without': 154,
#  'stopping.': 2,
#  'ii': 1,
#  'mrs.': 155,
#  'years': 36,
#  'older': 5,
#  'i,': 148,
#  'established': 9,
#  'reputation': 8,
#  'herself': 31,
#  'neighbors': 3,
#  'because': 79,
#  'she': 827,
#  'brought': 96,
#  '"by': 8,
#  'hand."': 3,
#  'expression': 18,
#  'meant,': 4,
#  'knowing': 31,
#  'her': 954,
#  'hand,': 67,
#  'much': 262,
#  'habit': 14,
#  'laying': 15,
#  'husband': 7,
#  'well': 115,
#  'supposed': 28,
#  'gargery': 8,
#  'hand.': 36,
#  'good-looking': 2,
#  'woman,': 17,
#  'sister;': 5,
#  'general': 38,
#  'must': 205,
#  'marry': 8,
#  'fair': 10,
#  'curls': 3,
#  'flaxen': 2,
#  'hair': 45,
#  'smooth': 6,
#  'face,': 28,
#  'very': 378,
#  'undecided': 3,
#  'blue': 32,
#  'somehow': 6,
#  'mixed': 3,
#  'whites.': 1,
#  'mild,': 1,
#  'good-natured,': 1,
#  'sweet-tempered,': 1,
#  'easy-going,': 1,
#  'foolish,': 1,
#  'dear': 173,
#  'fellow,--a': 1,
#  'sort': 33,
#  'hercules': 1,
#  'strength,': 5,
#  'weakness.': 1,
#  'joe,': 212,
#  'eyes,': 34,
#  'prevailing': 1,
#  'redness': 2,
#  'skin': 5,
#  'sometimes': 28,
#  'used': 43,
#  'wonder': 21,
#  'possible': 15,
#  'washed': 6,
#  'nutmeg-grater': 1,
#  'instead': 26,
#  'soap.': 1,
#  'tall': 3,
#  'bony,': 1,
#  'always': 164,
#  'wore': 19,
#  'apron,': 4,
#  'fastened': 6,
#  'figure': 26,
#  'behind': 61,
#  'loops,': 1,
#  'square': 4,
#  'impregnable': 1,
#  'bib': 1,
#  'front,': 3,
#  'stuck': 12,
#  'full': 45,
#  'pins': 1,
#  'needles.': 1,
#  'powerful': 7,
#  'merit': 3,
#  'herself,': 7,
#  'reproach': 3,
#  'against': 83,
#  'apron': 5,
#  'much.': 7,
#  'really': 39,
#  'reason': 51,
#  'why': 50,
#  'should': 349,
#  'worn': 11,
#  'all;': 3,
#  'why,': 19,
#  'did': 220,
#  'wear': 9,
#  'all,': 34,
#  'off,': 35,
#  'every': 93,
#  'day': 106,
#  'life.': 25,
#  "joe's": 49,
#  'forge': 17,
#  'adjoined': 2,
#  'house,': 46,
#  'wooden': 22,
#  'many': 88,
#  'dwellings': 1,
#  'country': 24,
#  'were,--most': 1,
#  'them,': 66,
#  'time.': 35,
#  'shut': 27,
#  'sitting': 30,
#  'alone': 16,
#  'kitchen.': 3,
#  'fellow-sufferers,': 2,
#  'confidences': 3,
#  'such,': 2,
#  'imparted': 9,
#  'confidence': 21,
#  'moment': 63,
#  'raised': 23,
#  'latch': 4,
#  'door': 57,
#  'peeped': 5,
#  'opposite': 21,
#  'chimney': 8,
#  'corner.': 6,
#  '"mrs.': 5,
#  'dozen': 10,
#  'you,': 166,
#  "she's": 23,
#  'making': 60,
#  "baker's": 1,
#  'dozen."': 1,
#  '"is': 59,
#  'she?"': 2,
#  'pip,"': 64,
#  'joe;': 18,
#  "what's": 16,
#  'worse,': 6,
#  'tickler': 7,
#  'her."': 10,
#  'dismal': 16,
#  'intelligence,': 3,
#  'twisted': 4,
#  'button': 2,
#  'waistcoat': 3,
#  'round,': 17,
#  'depression': 2,
#  'fire.': 23,
#  'wax-ended': 1,
#  'cane,': 1,
#  'collision': 1,
#  'tickled': 1,
#  'frame.': 2,
#  '"she': 18,
#  'sot': 1,
#  'down,"': 3,
#  'grab': 3,
#  'tickler,': 1,
#  'ram-paged': 2,
#  'out.': 40,
#  'did,"': 4,
#  'slowly': 30,
#  'clearing': 6,
#  'fire': 59,
#  'between': 112,
#  'lower': 12,
#  'bars': 6,
#  'poker,': 4,
#  'pip."': 26,
#  '"has': 5,
#  'gone': 66,
#  'joe?"': 24,
#  'treated': 8,
#  'larger': 2,
#  'species': 4,
#  'child,': 12,
#  'equal.': 2,
#  '"well,"': 14,
#  'dutch': 3,
#  'clock,': 5,
#  ...}
